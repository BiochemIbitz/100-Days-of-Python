# %% [markdown]
# <a href="https://colab.research.google.com/github/BiochemIbitz/100-Days-of-Python/blob/main/Language_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=29d4c975839e05fc0dd0f57b29fa4913b41739f6c1ea7ad87ef107afb852f2ae
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
# prompt: write a program to detect language

from langdetect import detect
text = "Esta es una frase en español."
language = detect(text)
print(language)
# Out:
# es

# %%
import langdetect
text = input("Enter a text in any language")
lang = langdetect.detect(text)
print(lang)
# Out:
# Enter a text in any languagemerci
# es

# %%
# prompt: write a program to detect language

from langdetect import detect
text = "Bawo ni o se wa"
language = detect(text)
print(language)
# Out:
# pl

# %%
# prompt: how to get the list of language contained in langdetect library

# !pip install pycountry
import pycountry

languages = list(pycountry.languages.values())
for language in languages:
  print(language.name)

# %%
# prompt:  list of language contained in langdetect library

# !pip install pycountry
import pycountry

# Import the correct object
from pycountry import languages

# Get a list of languages
languages = list(languages)

for language in languages:
  print(language.name)
# Out:
# Streaming output truncated to the last 5000 lines.
# Kumam
# Karamojong
# Numèè
# Tsikimba
# Kagoma
# Kunda
# Kaningdon-Nindem
# Koch
# Karaim
# Kuy
# Kadaru
# Koneraw
# Kam
# Keder
# Kwaja
# Kabuverdianu
# Kélé
# Keiga
# Kerewe
# Eastern Keres
# Kpessi
# Tese
# Keak
# Kei
# Kadar
# Kekchí
# Kela (Democratic Republic of Congo)
# Kemak
# Kenyang
# Kakwa
# Kaikadi
# Kamar
# Kera
# Kugbo
# Ket
# Akebu
# Kanikkaran
# West Kewa
# Kukna
# Kupia
# Kukele
# Kodava
# Northwestern Kolami
# Konda-Dora
# Korra Koraga
# Kota (India)
# Koya
# Kudiya
# Kurichiya
# Kannada Kurumba
# Kemiehua
# Kinnauri
# Kung
# Khunsari
# Kuk
# Koro (Côte d'Ivoire)
# Korwa
# Korku
# Kachhi
# Bilaspuri
# Kanjari
# Katkari
# Kurmukar
# Kharam Naga
# Kullu Pahari
# Kumaoni
# Koromfé
# Koyaga
# Kawe
# Komering
# Kube
# Kusunda
# Selangor Sign Language
# Gamale Kham
# Kaiwá
# Kunggari
# Karipúna
# Karingani
# Krongo
# Kaingang
# Kamoro
# Abun
# Kumbainggar
# Somyev
# Kobol
# Karas
# Karon Dori
# Kamaru
# Kyerung
# Khasi
# ...
